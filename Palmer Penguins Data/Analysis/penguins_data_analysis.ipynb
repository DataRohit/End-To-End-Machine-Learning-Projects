# %% [markdown]
# # Imports

# %%
# Data Manipulation and Linear Algebra
import pandas as pd
import numpy as np

# Plots
import seaborn as sns
sns.set_style("darkgrid")
import matplotlib.pyplot as plt

# #ignore warning messages 
# import warnings
# warnings.filterwarnings('ignore')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Loading and Viewing the Data

# %%
penguins_df = pd.read_csv("./datasets/penguins_data.csv")
penguins_df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8                207
# 329  Chinstrap      Dream            43.5           18.1                202
# 330  Chinstrap      Dream            49.6           18.2                193
# 331  Chinstrap      Dream            50.8           19.0                210
# 332  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 0           3750    male
# ...

# %% [markdown]
# ## Checking for Datatype and Null Values

# %%
penguins_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    int64
#  5   body_mass_g        333 non-null    int64
#  6   sex                333 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 18.3+ KB

# %%
penguins_df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# #### We Dont have any Null Values

# %%
penguins_df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# # Analysis

# %%
plt.figure(figsize=(15, 6), dpi=80)

title_font_dict = {"fontsize":16, "fontweight":"bold"}

ax1 = plt.subplot("131")
sns.countplot(penguins_df.species, ax=ax1)
ax1.set_title("Penguins Species Countplot", fontdict=title_font_dict)

ax2 = plt.subplot("132")
sns.countplot(penguins_df.island, ax=ax2)
ax2.set_title("Penguins Island Countplot", fontdict=title_font_dict)

ax3 = plt.subplot("133")
sns.countplot(penguins_df.sex, ax=ax3)
ax3.set_title("Penguins Sex Countplot", fontdict=title_font_dict)
# Out:
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/2102270864.py:5: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax1 = plt.subplot("131")
# E:\Program Files\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/2102270864.py:9: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax2 = plt.subplot("132")
# ...

# %%
plt.figure(figsize=(15, 6), dpi=80)

ax1 = plt.subplot("131")
sns.countplot(penguins_df.species, hue=penguins_df.sex, ax=ax1)
ax1.set_title("Penguins Species Countplot", fontdict=title_font_dict)

ax2 = plt.subplot("132")
sns.countplot(penguins_df.island, hue=penguins_df.sex, ax=ax2)
ax2.set_title("Penguins Island Countplot", fontdict=title_font_dict)
# Out:
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/554230639.py:3: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax1 = plt.subplot("131")
# E:\Program Files\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/554230639.py:7: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax2 = plt.subplot("132")
# ...

# %% [markdown]
# #### We have almost equal Males and Females in every specie and on Every Isnlad

# %%
plt.figure(figsize=(20, 15), dpi=80)

ax1 = plt.subplot("221")
sns.histplot(data=penguins_df, x="bill_length_mm", hue="sex", ax=ax1)
ax1.set_title("Penguins Bill Length (mm)", fontdict=title_font_dict)

ax2 = plt.subplot("222")
sns.histplot(data=penguins_df, x="bill_depth_mm", hue="sex", ax=ax2)
ax2.set_title("Penguins Bill Depth (mm)", fontdict=title_font_dict)

ax3 = plt.subplot("223")
sns.histplot(data=penguins_df, x="flipper_length_mm", hue="sex", ax=ax3)
ax3.set_title("Penguins Flipper Length (mm)", fontdict=title_font_dict)

ax4 = plt.subplot("224")
sns.histplot(data=penguins_df, x="body_mass_g", hue="sex", ax=ax4)
ax4.set_title("Penguins Body Mass (g)", fontdict=title_font_dict);
# Out:
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/463573088.py:3: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax1 = plt.subplot("221")
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/463573088.py:7: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax2 = plt.subplot("222")
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/463573088.py:11: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax3 = plt.subplot("223")
# ...

# %%
plt.figure(figsize=(20, 6), dpi=80)

ax1 = plt.subplot("131")
sns.scatterplot(data=penguins_df, x="bill_length_mm", y="bill_depth_mm", hue="species", ax=ax1)
ax1.set_title("Bill Length (mm) vs Bill Depth (mm) - Species")

ax2 = plt.subplot("132")
sns.scatterplot(data=penguins_df, x="bill_length_mm", y="bill_depth_mm", hue="island", ax=ax2)
ax2.set_title("Bill Length (mm) vs Bill Depth (mm) - Island")

ax3 = plt.subplot("133")
sns.scatterplot(data=penguins_df, x="bill_length_mm", y="bill_depth_mm", hue="sex", ax=ax3)
ax3.set_title("Bill Length (mm) vs Bill Depth (mm) - Sex");
# Out:
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/992385674.py:3: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax1 = plt.subplot("131")
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/992385674.py:7: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax2 = plt.subplot("132")
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/992385674.py:11: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax3 = plt.subplot("133")

# %%
plt.figure(figsize=(20, 6), dpi=80)

ax1 = plt.subplot("131")
sns.kdeplot(data=penguins_df, x="body_mass_g", hue="species", ax=ax1)
ax1.set_title("Body Mass (g) - Species")

ax2 = plt.subplot("132")
sns.kdeplot(data=penguins_df, x="body_mass_g", hue="island", ax=ax2)
ax2.set_title("Body Mass (g) - Island")

ax3 = plt.subplot("133")
sns.kdeplot(data=penguins_df, x="body_mass_g", hue="sex", ax=ax3)
ax3.set_title("Body Mass (g) - Sex");
# Out:
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/363017951.py:3: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax1 = plt.subplot("131")
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/363017951.py:7: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax2 = plt.subplot("132")
# C:\Users\ingob\AppData\Local\Temp/ipykernel_12124/363017951.py:11: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax3 = plt.subplot("133")

# %%
plt.figure(figsize=(20, 6), dpi=100)

ax1 = plt.subplot2grid((1,3),(0,0))
plt.pie(penguins_df.species.value_counts(), autopct='%.1f%%', labels=penguins_df.species.value_counts().index)
ax1.set_title("Species Distribution")

ax2 = plt.subplot2grid((1,3),(0,1))
plt.pie(penguins_df.island.value_counts(), autopct='%.1f%%', labels=penguins_df.island.value_counts().index)
ax2.set_title("Island Distribution")

ax3 = plt.subplot2grid((1,3),(0,2))
plt.pie(penguins_df.sex.value_counts(), autopct='%.1f%%', labels=penguins_df.sex.value_counts().index)
ax3.set_title("Gender Distribution")

plt.show()

# %%
plt.figure(figsize=(20, 15), dpi=100)

ax1 = plt.subplot(221)
sns.violinplot("species", "bill_length_mm", hue="sex", data=penguins_df, split=True, ax=ax1)
ax1.set_title("Species vs Bill Length (mm)", fontdict=title_font_dict)

ax2 = plt.subplot(222)
sns.violinplot("species", "bill_depth_mm", hue="sex", data=penguins_df, split=True, ax=ax2)
ax2.set_title("Species vs Bill Depth (mm)", fontdict=title_font_dict)

ax3 = plt.subplot(223)
sns.violinplot("species", "flipper_length_mm", hue="sex", data=penguins_df, split=True, ax=ax3)
ax3.set_title("Species vs Flipper Length (mm)", fontdict=title_font_dict)

ax4 = plt.subplot(224)
sns.violinplot("species", "body_mass_g", hue="sex", data=penguins_df, split=True, ax=ax4)
ax4.set_title("Species vs Body Mass (g)", fontdict=title_font_dict)
# Out:
# E:\Program Files\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Program Files\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Program Files\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
plt.figure(figsize=(20, 15), dpi=100)

ax1 = plt.subplot(221)
sns.violinplot("island", "bill_length_mm", hue="sex", data=penguins_df, split=True, ax=ax1)
ax1.set_title("Island vs Bill Length (mm)", fontdict=title_font_dict)

ax2 = plt.subplot(222)
sns.violinplot("island", "bill_depth_mm", hue="sex", data=penguins_df, split=True, ax=ax2)
ax2.set_title("Island vs Bill Depth (mm)", fontdict=title_font_dict)

ax3 = plt.subplot(223)
sns.violinplot("island", "flipper_length_mm", hue="sex", data=penguins_df, split=True, ax=ax3)
ax3.set_title("Island vs Flipper Length (mm)", fontdict=title_font_dict)

ax4 = plt.subplot(224)
sns.violinplot("island", "body_mass_g", hue="sex", data=penguins_df, split=True, ax=ax4)
ax4.set_title("Island vs Body Mass (g)", fontdict=title_font_dict)
# Out:
# E:\Program Files\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Program Files\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Program Files\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %% [markdown]
# # Preparing Data

# %%
cols_to_encode = ["island", "sex"]
for col in cols_to_encode:
    dummy_df = pd.get_dummies(penguins_df[col], prefix=col)
    penguins_df = pd.concat([penguins_df, dummy_df], axis=1)
    del penguins_df[col]

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(penguins_df, penguins_df['species']):
    train = penguins_df.loc[train_index]
    test = penguins_df.loc[test_index]

# %%
X_train = train.drop("species", axis=1)
y_train = train["species"]

X_test = test.drop("species", axis=1)
y_test = test["species"]

# %% [markdown]
# # Machine Learning Model

# %% [markdown]
# ## Using RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score

rfc_classifier = RandomForestClassifier()
rfc_classifier.fit(X_train, y_train)

y_pred = rfc_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
kfold_accuracy = cross_val_score(estimator = rfc_classifier, X = X_train, y = y_train, cv = 10).mean()

# %%
print(f"Classifier Accuracy Score : {round(accuracy, 4)*100}%", "\n")

print(f"Average K-Fold Accuracy Score : {round(kfold_accuracy, 4)*100}%", "\n")

print(f"Confusion Matrix\n{confusion_matrix(y_test, y_pred)}", "\n")

print(f"Classification Report\n{classification_report(y_test, y_pred)}")
# Out:
# Classifier Accuracy Score : 100.0%
#
# Average K-Fold Accuracy Score : 98.85000000000001%
#
# Confusion Matrix
# [[29  0  0]
#  [ 0 14  0]
#  [ 0  0 24]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        29
#    Chinstrap       1.00      1.00      1.00        14
#       Gentoo       1.00      1.00      1.00        24
#
#     accuracy                           1.00        67
#    macro avg       1.00      1.00      1.00        67
# weighted avg       1.00      1.00      1.00        67

# %%
# Saving RandomForestClassifier Model for Webapp Use
# Saving our Model
import pickle

filename = '../rfc_model.pkl'
pickle.dump(rfc_classifier, open(filename, 'wb'))
